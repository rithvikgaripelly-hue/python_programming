# %% [markdown]
# # data types in python
# 1. different vatype of values assigned to variable
# 2. basically 3 data types are in python
# 3. int(integer) - numerical values like 1,2,3,4....n
# 4. str(string) - charectars examples "abcd", "ghjk", "qwerty"
# 5. float(decimals) - numerical with decimal - 10.25,100.25,125.25

# %%
name= "vikas"
age=25
data="123"
salary=100023.25
print(name)
print(age)
print(data)
print(salary)
print(type(name))
print(type(age))
print(type(data))
print(type(salary))
# Out:
# vikas
# 25
# 123
# 100023.25
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# concatenations
a=100
b=500
print(a+b)
# Out:
# 600

# %%
n1="python"
n2="programming"
print(n1+n2)
# Out:
# pythonprogramming

# %%
a=100
b="300"
print(a+int(b))
# Out:
# 400
